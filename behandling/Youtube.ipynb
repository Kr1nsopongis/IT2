# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("youtube.csv", delimiter=",", engine= "python")
data.head()



x = data["Youtuber"]
y = data["subscribers"]

plt.barh(x,y)
plt.show()
